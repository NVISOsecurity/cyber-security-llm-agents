# %%
import os
os.chdir('..')
print(os.getcwd())
# Out:
# /home/draman/repos/cyber-security-llm-agents

# %%
from run_agents import run_scenario
from actions.caldera_actions import actions
import json

# %% [markdown]
# # Scenario 1 - EDR Bypassing and Credential Dumping

# %% [markdown]
# ## Step 1 - Hello, Caldera

# %%
print(json.dumps(actions["HELLO_CALDERA"], indent=4))
# Out:
# [
#     {
#         "message": "Use powershell to display a message box on the desktop of the active Caldera agent containing a cyber security joke.",
#         "summary_method": "last_msg",
#         "agent": "caldera_agent"
#     }
# ]

# %%
run_scenario("HELLO_CALDERA")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to caldera_agent):
#
# Get the ID of the active Caldera operation.
# Context:
# Replace this placeholder with the ID of the active Caldera operation.
#
# --------------------------------------------------------------------------------
# caldera_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_fCwPyDgUNBDi5dRYmkpdTRZb): caldera_api_get_operation_info *****
# Arguments:
# {}
# ***********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION caldera_api_get_operation_info...
# task_coordinator_agent (to caldera_agent):
#
# task_coordinator_agent (to caldera_agent):
#
# ...

# %% [markdown]
# ## Step 2 - Retrieve basic information about the active Caldera agent

# %%
print(json.dumps(actions["DETECT_AGENT_PRIVILEGES"], indent=4))
# Out:
# [
#     {
#         "message": "Get the current user's privileges on the active Caldera agent using a Powershell command.",
#         "summary_method": "last_msg",
#         "carryover": "Replace this placeholder with the list of ALL privileges.",
#         "agent": "caldera_agent"
#     },
#     {
#         "message": "List all the users privileges in a structured table and add a conclusion on if the agent is running with standard user, administrator or system privileges.",
#         "summary_method": "last_msg",
#         "agent": "text_analyst_agent"
#     }
# ]

# %%
run_scenario("DETECT_AGENT_PRIVILEGES")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to caldera_agent):
#
# Get the ID of the active Caldera operation.
# Context:
# Replace this placeholder with the ID of the active Caldera operation.
#
# --------------------------------------------------------------------------------
# caldera_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_fCwPyDgUNBDi5dRYmkpdTRZb): caldera_api_get_operation_info *****
# Arguments:
# {}
# ***********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION caldera_api_get_operation_info...
# task_coordinator_agent (to caldera_agent):
#
# task_coordinator_agent (to caldera_agent):
#
# ...

# %% [markdown]
# ## Step 3 - Detect the EDR Running on the agent

# %%
print(json.dumps(actions["DETECT_EDR"], indent=4))
# Out:
# [
#     {
#         "message": "Download https://raw.githubusercontent.com/tsale/EDR-Telemetry/main/README.md",
#         "summary_method": "last_msg",
#         "carryover": "Replace this placeholder with the list of ALL security products mentioned in the README. Add a title to the list.",
#         "agent": "internet_agent"
#     },
#     {
#         "message": "List all Windows services on the active Caldera agent",
#         "summary_method": "last_msg",
#         "carryover": "Replace this placeholder with the list of ALL Windows service names",
#         "agent": "caldera_agent"
#     },
#     {
#         "message": "Identify which security services are likely running on the active Caldera agent based on the provided context.\n            Do this by comparing the list of running services with the list of popular security products.\n            It's possible that multiple security agents are running.",
#         "summary_method": "reflection_with_llm",
# ...

# %%
run_scenario("DETECT_EDR")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to caldera_agent):
#
# Get the ID of the active Caldera operation.
# Context:
# Replace this placeholder with the ID of the active Caldera operation.
#
# --------------------------------------------------------------------------------
# caldera_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_fCwPyDgUNBDi5dRYmkpdTRZb): caldera_api_get_operation_info *****
# Arguments:
# {}
# ***********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION caldera_api_get_operation_info...
# task_coordinator_agent (to caldera_agent):
#
# task_coordinator_agent (to caldera_agent):
#
# ...

# %% [markdown]
# ## Step 4 - Identify a technique not logged by the identified EDR detection

# %%
run_scenario("IDENTIFY_EDR_BYPASS_TECHNIQUES")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to internet_agent):
#
# Identify the EDR telemetry gaps for Elastic using https://raw.githubusercontent.com/tsale/EDR-Telemetry/main/EDR_telem.json
# Context:
# Output the list of the telemetry sub-categories. Include a title above the list making it clear these are telemetry gaps.
#
# --------------------------------------------------------------------------------
# internet_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_2rwlLM4J1YKilgWmtfkYAI0u): detect_telemetry_gaps *****
# Arguments:
# {"url":"https://raw.githubusercontent.com/tsale/EDR-Telemetry/main/EDR_telem.json","edr_name":"Elastic"}
# **************************************************************************************
#
# ...

# %% [markdown]
# ## Step 5 - Elevate privileges by hijacking Windows service Execution Flow: Path Interception by Unquoted Path (T1574.009)

# %%
run_scenario("ELEVATE_PRIVILEGES")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to caldera_agent):
#
# Get the ID of the active Caldera operation.
# Context:
# Replace this placeholder with the ID of the active Caldera operation.
#
# --------------------------------------------------------------------------------
# caldera_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_fCwPyDgUNBDi5dRYmkpdTRZb): caldera_api_get_operation_info *****
# Arguments:
# {}
# ***********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION caldera_api_get_operation_info...
# task_coordinator_agent (to caldera_agent):
#
# task_coordinator_agent (to caldera_agent):
#
# ...

# %% [markdown]
# ## Step 6 - Download and run a credential harvesting tool and exfiltrate the results

# %%
run_scenario("DUMP_LSASS")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to caldera_agent):
#
# Get the ID of the active Caldera operation.
# Context:
# Replace this placeholder with the ID of the active Caldera operation.
#
# --------------------------------------------------------------------------------
# caldera_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_fCwPyDgUNBDi5dRYmkpdTRZb): caldera_api_get_operation_info *****
# Arguments:
# {}
# ***********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION caldera_api_get_operation_info...
# task_coordinator_agent (to caldera_agent):
#
# task_coordinator_agent (to caldera_agent):
#
# ...

# %% [markdown]
# # Scenario 2 - Automated TI report parsing & technique selection

# %%
run_scenario("TTP_REPORT_TO_TECHNIQUES")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# task_coordinator_agent (to internet_agent):
#
# Download the HTML report at https://www.microsoft.com/en-us/security/blog/2024/04/22/analyzing-forest-blizzards-custom-post-compromise-tool-for-exploiting-cve-2022-38028-to-obtain-credentials/
# Context:
# Replace this placeholder with all the MITRE techniques extracted from the downloaded report.
#
# --------------------------------------------------------------------------------
# internet_agent (to task_coordinator_agent):
#
# ***** Suggested tool call (call_wPjin33EyvYJXNj8mH8atVPc): download_web_page *****
# Arguments:
# {"url":"https://www.microsoft.com/en-us/security/blog/2024/04/22/analyzing-forest-blizzards-custom-post-compromise-tool-for-exploiting-cve-2022-38028-to-obtain-credentials/"}
# ...
